# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("C:/Users/Ashish/Desktop/expert's hub/data.csv")

# %%
data
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
# date             4600 non-null object
# price            4600 non-null float64
# bedrooms         4600 non-null int64
# bathrooms        4600 non-null float64
# sqft_living      4600 non-null int64
# sqft_lot         4600 non-null int64
# floors           4600 non-null float64
# waterfront       4600 non-null int64
# view             4600 non-null int64
# condition        4600 non-null int64
# sqft_above       4600 non-null int64
# sqft_basement    4600 non-null int64
# yr_built         4600 non-null int64
# yr_renovated     4600 non-null int64
# street           4600 non-null object
# city             4600 non-null object
# statezip         4600 non-null object
# country          4600 non-null object
# dtypes: float64(3), int64(10), object(5)
# memory usage: 647.0+ KB

# %%
data['statezip'].value_counts()
# Out:
# WA 98103    148
# WA 98052    135
# WA 98117    132
# WA 98115    130
# WA 98006    110
#            ...
# WA 98047      6
# WA 98288      3
# WA 98354      2
# WA 98050      2
# WA 98068      1
# Name: statezip, Length: 77, dtype: int64

# %%
#city=data.drop(columns='city')
#street=data.drop(columns='street')
#country=data.drop(columns='country')
#statezip=data.drop(columns='statezip')
#date=data.drop(columns='date')
data.drop(columns=['city','street','country','statezip','date'],inplace=True)

# %%
data
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05         3       1.50         1340      7912     1.5
# 1     2.384000e+06         5       2.50         3650      9050     2.0
# 2     3.420000e+05         3       2.00         1930     11947     1.0
# 3     4.200000e+05         3       2.25         2000      8030     1.0
# 4     5.500000e+05         4       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05         3       1.75         1510      6360     1.0
# 4596  5.343333e+05         3       2.50         1460      7573     2.0
# 4597  4.169042e+05         3       2.50         3010      7014     2.0
# 4598  2.034000e+05         4       2.00         2090      6630     1.0
# 4599  2.206000e+05         3       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
#training and testing
from sklearn.model_selection import train_test_split
x_train,x_test=train_test_split(data.drop(columns='price'))
y_train,y_test=train_test_split(data['price'])

# %%
#linear regression
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
predict=reg.predict(x_test)
print("Linear Regression:")
reg.score(x_train,y_train)
# Out:
# Linear Regression:
# 0.0032533064115360943

# %%
#Random forest regressor
from sklearn.ensemble import RandomForestRegressor
reg1=RandomForestRegressor()
reg1.fit(x_train,y_train)
predict1=reg.predict(x_test)
print("Random Forest")
reg1.score(x_train,y_train)
# Out:
# C:\Users\Ashish\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Random Forest
# 0.8708259408221055

# %%
#Decision tree
from sklearn.tree import DecisionTreeRegressor
reg2=DecisionTreeRegressor()
reg2.fit(x_train,y_train)
predict2=reg2.predict(x_test)
reg2.score(x_train,y_train)
# Out:
# 0.9999677119150852

# %%
#mean square and mean absolute error
from sklearn.metrics import mean_absolute_error,mean_squared_error
prediction=[predict,predict1,predict2]
algorithms=["LinearRegression","RandomForest","DecisionTree"]
c=0
for i in prediction:
        print(algorithms[c], "\n", "MeanSquaredError-",mean_squared_error(y_test,i),"\n","MeanAbsoluteError-",mean_absolute_error(y_test,i))
        c+=1
# Out:
# LinearRegression
#  MeanSquaredError- 140301271081.56598
#  MeanAbsoluteError- 248514.3948382686
# RandomForest
#  MeanSquaredError- 140301271081.56598
#  MeanAbsoluteError- 248514.3948382686
# DecisionTree
#  MeanSquaredError- 309044671019.67645
#  MeanAbsoluteError- 354978.3416889565

# %%
plt.hist(predict)
# Out:
# (array([  6.,  14.,  41.,  69., 331., 421., 216.,  43.,   7.,   2.]),
#  array([407339.09723003, 435522.00314154, 463704.90905305, 491887.81496456,
#         520070.72087607, 548253.62678759, 576436.5326991 , 604619.43861061,
#         632802.34452212, 660985.25043363, 689168.15634514]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(predict1)
# Out:
# (array([  6.,  14.,  41.,  69., 331., 421., 216.,  43.,   7.,   2.]),
#  array([407339.09723003, 435522.00314154, 463704.90905305, 491887.81496456,
#         520070.72087607, 548253.62678759, 576436.5326991 , 604619.43861061,
#         632802.34452212, 660985.25043363, 689168.15634514]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(predict2)
# Out:
# (array([884., 235.,  21.,   8.,   0.,   1.,   0.,   0.,   0.,   1.]),
#  array([      0.,  706250., 1412500., 2118750., 2825000., 3531250.,
#         4237500., 4943750., 5650000., 6356250., 7062500.]),
#  <a list of 10 Patch objects>)
